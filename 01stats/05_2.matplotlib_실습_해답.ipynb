# %% [markdown]
# # Matplotlib 연습문제
#
# 일단 필요한 package를 import하고 매직 명령어를 사용하여 jupyter notebook에서 그래프가 표시 될 수 있도록 한다.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %% [markdown]
# 1. 아래의 코드를 수행하여 그래프로 표시할 데이터를 만드시오.
# subplot을 활용하여 아래와 같은 결과를 그래프로 그리시오.
#
# ```
# x1 = np.linspace(0.0, 5.0)
# x2 = np.linspace(0.0, 2.0)
#
# y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
# y2 = np.cos(2 * np.pi * x2)
# ```

# %%
x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)

y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

# TODO

ax1 = plt.subplot(2, 1, 1)
plt.plot(x1, y1, 'yo-')
plt.title('A tale of 2 subplots')
plt.ylabel('Damped oscillation')
print(ax1)

ax2 = plt.subplot(2, 1, 2)
plt.plot(x2, y2, 'r.-')
plt.xlabel('time (s)')
plt.ylabel('Undamped')
print(ax2)

plt.tight_layout()
plt.show()
# Out:
# AxesSubplot(0.125,0.536818;0.775x0.343182)
# AxesSubplot(0.125,0.125;0.775x0.343182)

# %% [markdown]
# 2. 다음과 같이 sine 그래프와 cosine 그래프를 하나의 그래프로 표시하시오.
# 선의 모양, 색깔을 다르게 하고 legend를 표시하시오.

# %%
x = np.linspace(0,10,100)

# TODO
sine = np.sin(x)
cosine = np.cos(x)
plt.plot(x, sine, 'r-',label='sine')
plt.plot(x, cosine, 'g--', label='cosine')
plt.legend(loc='upper right')

# %% [markdown]
# 3. 다음과 같은 정규분포 데이터를 만들고 histogram을 그려보시오.
# ```
# data = np.random.normal(5,3,1000)
# ```

# %%
data = np.random.normal(5,3,1000)

plt.hist(data)
# Out:
# (array([  5.,  26.,  96., 198., 287., 234., 110.,  32.,  10.,   2.]),
#  array([-4.52715705, -2.44594645, -0.36473585,  1.71647475,  3.79768535,
#          5.87889595,  7.96010655, 10.04131715, 12.12252775, 14.20373835,
#         16.28494895]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# 4. 다음과 같은 데이터를 만들고 산점도를 그려보시오.
#
# ```
# x = np.random.rand(30)
# y = 2*x + 3 + np.random.randn(30)
# ```

# %%
x = np.random.rand(30)
y = 2*x + 3 + np.random.randn(30)

plt.plot(x, y, 'r.')
plt.title('scatter plot')
# Out:
# Text(0.5, 1.0, 'scatter plot')
